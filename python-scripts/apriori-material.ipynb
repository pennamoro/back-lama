# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("receitas-materiais.csv", header=None, skiprows=1, names=['materiais_concatenados'])
df['materiais_concatenados'] = df['materiais_concatenados'].str.split(', ')
new_df = pd.DataFrame(df['materiais_concatenados'].to_list())
result_df = pd.concat([df, new_df], axis=1)

result_df.replace(np.nan, 0, inplace=True)
result_df.drop(columns=['materiais_concatenados'], inplace=True)

df = result_df
df.head(10)
# Out:
#                                0                                    1  \
# 0      Mini Gorros de Papai Noel            Lã algodão 4 - Azul Claro
# 1              Chapéu de Inverno      Lã Amigurumi Soft - Azul Escuro
# 2  Olhos de Gato de Plástico 6mm                   Óculos de Mergulho
# 3          Boca de Cachorro 12mm   Lã Amigurumi  Pelúcia - Rosa Claro
# 4   Lã Amigurumi  Pelúcia - Rosa                                    0
# 5                  Óculos de Sol  Lã Amigurumi  Pelúcia - Rosa Escuro
# 6            Barbante 8 - Branco                 Barbante 4 - Laranja
# 7                  Chapéu de Sol                Focinho de Porco 20mm
# 8        Agulha de Crochê 4,0 mm            Lã algodão 4 - Roxo Claro
# 9      Mini Gorros de Papai Noel                 Bolinhas decorativas
#
#                                     2                                 3
# 0            Barbante Natural 2 - Cru                                 0
# 1                                   0                                 0
# 2  Lã Amigurumi Soft - Vermelho Claro          Lã Amigurumi Soft - Rosa
# 3                                   0                                 0
# 4                                   0                                 0
# 5                                   0                                 0
# 6                                   0                                 0
# 7           Lã Amigurumi Soft - Verde  Lã Amigurumi  Pelúcia - Vermelho
# 8             Lã algodão 4 - Vermelho                                 0
# 9                                   0                                 0

# %%
def removeAllZeros(l):
    return list(filter(lambda x: x != 0, l))

# %%
first_list = []
for index, row in df.iterrows():
    listOfMaterial = row.values.tolist()
    listOfMaterial = removeAllZeros(listOfMaterial)

    first_list.append(listOfMaterial)

list_all_material = [[item.split(' -')[0] for item in sublist] for sublist in first_list]

list_all_material[0:10]
# Out:
# [['Mini Gorros de Papai Noel', 'Lã algodão 4', 'Barbante Natural 2'],
#  ['Chapéu de Inverno', 'Lã Amigurumi Soft'],
#  ['Olhos de Gato de Plástico 6mm',
#   'Óculos de Mergulho',
#   'Lã Amigurumi Soft',
#   'Lã Amigurumi Soft'],
#  ['Boca de Cachorro 12mm', 'Lã Amigurumi  Pelúcia'],
#  ['Lã Amigurumi  Pelúcia'],
#  ['Óculos de Sol', 'Lã Amigurumi  Pelúcia'],
#  ['Barbante 8', 'Barbante 4'],
#  ['Chapéu de Sol',
#   'Focinho de Porco 20mm',
#   'Lã Amigurumi Soft',
#   'Lã Amigurumi  Pelúcia'],
#  ['Agulha de Crochê 4,0 mm', 'Lã algodão 4', 'Lã algodão 4'],
#  ['Mini Gorros de Papai Noel', 'Bolinhas decorativas']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(list_all_material).transform(list_all_material)
df = pd.DataFrame(te_ary, columns=te.columns_)

df
# Out:
#      Agulha de Crochê 10,0 mm  Agulha de Crochê 2,5 mm  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ..                        ...                      ...
# 994                     False                    False
# 995                     False                    False
# 996                     False                    False
# 997                     False                    False
# 998                     False                    False
#
#      Agulha de Crochê 3,5 mm  Agulha de Crochê 4,0 mm  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                      False                    False
# ..                       ...                      ...
# 994                    False                    False
# 995                    False                    False
# 996                    False                    False
# 997                    False                    False
# 998                    False                     True
#
#      Agulha de Crochê 4,5 mm  Agulha de Crochê 5,5 mm  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                      False                    False
# ..                       ...                      ...
# 994                    False                    False
# 995                    False                    False
# 996                    False                    False
# 997                    False                    False
# 998                    False                    False
#
#      Agulha de Crochê 8,0 mm  Agulha de Crochê 9,0 mm  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                      False                    False
# ..                       ...                      ...
# 994                    False                    False
# 995                    False                    False
# 996                    False                    False
# 997                    False                    False
# 998                    False                    False
#
#      Agulha de Crochê Tunisiano 10,0 mm  Agulha de Crochê Tunisiano 2,0 mm  \
# 0                                 False                              False
# 1                                 False                              False
# 2                                 False                              False
# 3                                 False                              False
# 4                                 False                              False
# ..                                  ...                                ...
# 994                               False                              False
# 995                               False                              False
# 996                               False                              False
# 997                               False                              False
# 998                               False                              False
#
#      ...  Olhos de Cachorro de Pelúcia 12mm  Olhos de Gato de Plástico 6mm  \
# 0    ...                              False                          False
# 1    ...                              False                          False
# 2    ...                              False                           True
# 3    ...                              False                          False
# 4    ...                              False                          False
# ..   ...                                ...                            ...
# 994  ...                              False                          False
# 995  ...                              False                          False
# 996  ...                              False                          False
# 997  ...                              False                          False
# 998  ...                              False                          False
#
#      Olhos de Gato de Plástico 8mm  Pequenas Caixas de Presente  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# ..                             ...                          ...
# 994                          False                        False
# 995                          False                        False
# 996                          False                        False
# 997                          False                        False
# 998                          False                        False
#
#      Óculos de Esportes  Óculos de Leitura  Óculos de Mergulho  \
# 0                 False              False               False
# 1                 False              False               False
# 2                 False              False                True
# 3                 False              False               False
# 4                 False              False               False
# ..                  ...                ...                 ...
# 994               False              False               False
# 995               False              False               False
# 996                True              False               False
# 997               False              False               False
# 998               False              False               False
#
#      Óculos de Natação  Óculos de Segurança  Óculos de Sol
# 0                False                False          False
# 1                False                False          False
# 2                False                False          False
# 3                False                False          False
# 4                False                False          False
# ..                 ...                  ...            ...
# 994              False                False          False
# 995              False                False          False
# 996              False                 True          False
# 997              False                False          False
# 998              False                False          False
#
# [999 rows x 96 columns]

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support = 0.01, use_colnames= True)
frequent_itemsets.sort_values(by=['support'], ascending= False)
# Out:
#      support                                           itemsets
# 0   0.266266                          (Agulha de Crochê 4,0 mm)
# 33  0.249249                            (Lã Amigurumi  Pelúcia)
# 34  0.245245                                (Lã Amigurumi Soft)
# 38  0.151151                                     (Lã algodão 8)
# 36  0.126126                                     (Lã algodão 4)
# ..       ...                                                ...
# 52  0.011011                              (Óculos de Segurança)
# 87  0.010010             (Óculos de Sol, Lã Amigurumi  Pelúcia)
# 65  0.010010         (Boca de Gato 10mm, Lã Amigurumi  Pelúcia)
# 95  0.010010  (Agulha de Crochê 4,0 mm, Barbante 4, Lã algod...
# 72  0.010010              (Lã Amigurumi Soft, Chapéu de Páscoa)
#
# [100 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric = 'confidence', min_threshold= 0.5)
sorted_rules = rules.sort_values(by=['confidence'], ascending= False).drop(['antecedent support', 'consequent support', 'leverage', 'conviction', 'support', 'zhangs_metric'], axis=1)
sorted_rules
# Out:
#                             antecedents                consequents  \
# 36           (Lã algodão 4, Barbante 8)  (Agulha de Crochê 4,0 mm)
# 35           (Barbante 4, Lã algodão 8)  (Agulha de Crochê 4,0 mm)
# 37           (Lã algodão 8, Barbante 8)  (Agulha de Crochê 4,0 mm)
# 38         (Lã algodão 8, Lã algodão 4)  (Agulha de Crochê 4,0 mm)
# 3                        (Lã algodão 8)  (Agulha de Crochê 4,0 mm)
# 23  (Olhos de Cachorro de Pelúcia 12mm)    (Lã Amigurumi  Pelúcia)
# 1                          (Barbante 8)  (Agulha de Crochê 4,0 mm)
# 34           (Barbante 4, Lã algodão 4)  (Agulha de Crochê 4,0 mm)
# 18              (Focinho de Porco 18mm)        (Lã Amigurumi Soft)
# 0                          (Barbante 4)  (Agulha de Crochê 4,0 mm)
# 2                        (Lã algodão 4)  (Agulha de Crochê 4,0 mm)
# 7                (Boca de Sorriso 15mm)        (Lã Amigurumi Soft)
# 14                      (Chapéu de Sol)        (Lã Amigurumi Soft)
# 17               (Focinho de Gato 10mm)    (Lã Amigurumi  Pelúcia)
# 4                 (Boca de Boneca 12mm)        (Lã Amigurumi Soft)
# 15           (Focinho de Cachorro 12mm)    (Lã Amigurumi  Pelúcia)
# 16           (Focinho de Cachorro 12mm)        (Lã Amigurumi Soft)
# 13                   (Chapéu de Páscoa)        (Lã Amigurumi Soft)
# 19              (Focinho de Porco 20mm)    (Lã Amigurumi  Pelúcia)
# 33                  (Óculos de Natação)        (Lã Amigurumi Soft)
# 22     (Olhos de Cachorro de Botão 8mm)    (Lã Amigurumi  Pelúcia)
# 29     (Olhos de Cachorro de Botão 8mm)        (Lã Amigurumi Soft)
# 21     (Olhos de Cachorro de Botão 6mm)    (Lã Amigurumi  Pelúcia)
# 28     (Olhos de Cachorro de Botão 6mm)        (Lã Amigurumi Soft)
# 5               (Boca de Cachorro 12mm)        (Lã Amigurumi Soft)
# 11                    (Chapéu de Palha)    (Lã Amigurumi  Pelúcia)
# 12                    (Chapéu de Palha)        (Lã Amigurumi Soft)
# 8                (Boca de Sorriso 20mm)    (Lã Amigurumi  Pelúcia)
# 24      (Olhos de Gato de Plástico 6mm)    (Lã Amigurumi  Pelúcia)
# 31                 (Óculos de Esportes)        (Lã Amigurumi Soft)
# 32                 (Óculos de Mergulho)        (Lã Amigurumi Soft)
# 20              (Focinho de Porco 20mm)        (Lã Amigurumi Soft)
# 27                      (Óculos de Sol)    (Lã Amigurumi  Pelúcia)
# 6                   (Boca de Gato 10mm)    (Lã Amigurumi  Pelúcia)
# 25                 (Óculos de Esportes)    (Lã Amigurumi  Pelúcia)
# 26                 (Óculos de Mergulho)    (Lã Amigurumi  Pelúcia)
# 9                   (Chapéu de Inverno)    (Lã Amigurumi  Pelúcia)
# 10                  (Chapéu de Inverno)        (Lã Amigurumi Soft)
# 30      (Olhos de Gato de Plástico 6mm)        (Lã Amigurumi Soft)
#
#     confidence      lift
# 36    1.000000  3.755639
# 35    0.923077  3.466744
# 37    0.913043  3.429062
# 38    0.884615  3.322296
# 3     0.781457  2.934870
# 23    0.777778  3.120482
# 1     0.777778  2.921053
# 34    0.769231  2.888953
# 18    0.764706  3.118127
# 0     0.750000  2.816729
# 2     0.746032  2.801826
# 7     0.736842  3.004511
# 14    0.722222  2.944898
# 17    0.722222  2.897590
# 4     0.687500  2.803316
# 15    0.684211  2.745086
# 16    0.684211  2.789903
# 13    0.666667  2.718367
# 19    0.650000  2.607831
# 33    0.647059  2.638415
# 22    0.636364  2.553122
# 29    0.636364  2.594805
# 21    0.631579  2.533925
# 28    0.631579  2.575295
# 5     0.615385  2.509262
# 11    0.611111  2.451807
# 12    0.611111  2.491837
# 8     0.611111  2.451807
# 24    0.608696  2.442116
# 31    0.600000  2.446531
# 32    0.600000  2.446531
# 20    0.600000  2.446531
# 27    0.588235  2.360028
# 6     0.588235  2.360028
# 25    0.560000  2.246747
# 26    0.550000  2.206627
# 9     0.550000  2.206627
# 10    0.550000  2.242653
# 30    0.521739  2.127418

# %%
sorted_rules['antecedents'] = sorted_rules['antecedents'].apply(lambda x: list(x))
sorted_rules['consequents'] = sorted_rules['consequents'].apply(lambda x: list(x))

sorted_rules.to_csv("regras-materiais.csv", index=False)

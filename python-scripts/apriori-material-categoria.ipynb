# %%
# SELECT
#     x.id_receita,
#     STRING_AGG(c.descricao || ', ' || m.nome, ', ') AS receitas_concatenadas
# FROM
#     receita_separada_categoria x
# JOIN
#     categoria c ON x.id_categoria = c.id_categoria
# JOIN
#     receita_utiliza_material y ON x.id_receita = y.id_receita
# JOIN
#     material m ON y.id_material = m.id_material
# GROUP BY
#     x.id_receita;

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("receitas-material-categoria.csv", header=None, skiprows=1, names=['materiais_concatenados'])
df['materiais_concatenados'] = df['materiais_concatenados'].str.split(', ')
new_df = pd.DataFrame(df['materiais_concatenados'].to_list())
result_df = pd.concat([df, new_df], axis=1)

result_df.replace(np.nan, 0, inplace=True)
result_df.drop(columns=['materiais_concatenados'], inplace=True)

df = result_df
df.head(10)
# Out:
#                        0                              1                 2   \
# 116                     0                              0                 0
# 87                  Meias  Lã algodão 2 - Vermelho Claro             Meias
# 71                Coletes          Lã algodão 4 - Marrom           Coletes
# 68                  Natal    Barbante 4 - Vermelho Claro  Jogos Americanos
# 51                 Bolsas        Barbante 4 - Azul Claro            Bolsas
# 80   Capas para Almofadas        Agulha de Crochê 3,5 mm         Almofadas
# 70              Babadores            Barbante 2 - Branco         Babadores
# 52               Vestidos            Barbante 2 - Branco          Vestidos
# 92   Cestas Organizadoras        Agulha de Crochê 3,5 mm       Porta-Lápis
# 101             Cachecois   Lã algodão 4 - Amarelo Claro         Cachecois
#
#                                     3                     4   \
# 116                                  0                     0
# 87             Agulha de Crochê 2,5 mm                     0
# 71             Agulha de Crochê 3,5 mm                     0
# 68         Barbante 4 - Vermelho Claro           Porta-Copos
# 51   Agulha de Crochê Tunisiano 3,5 mm                     0
# 80             Agulha de Crochê 3,5 mm  Capas para Almofadas
# 70          Barbante 2 - Amarelo Claro             Babadores
# 52             Agulha de Crochê 3,0 mm                     0
# 92             Agulha de Crochê 3,5 mm  Cestas Organizadoras
# 101      Lã algodão 4 - Vermelho Claro             Cachecois
#
#                               5            6                         7   \
# 116                            0            0                         0
# 87                             0            0                         0
# 71                             0            0                         0
# 68   Barbante 4 - Vermelho Claro        Natal       Barbante 4 - Branco
# 51                             0            0                         0
# 80        Lã algodão 4 - Laranja    Almofadas    Lã algodão 4 - Laranja
# 70       Agulha de Crochê 2,0 mm    Babadores  Barbante 2 - Azul Escuro
# 52                             0            0                         0
# 92        Lã Amigurumi  - Branco  Porta-Lápis    Lã Amigurumi  - Branco
# 101      Agulha de Crochê 4,0 mm    Cachecois       Agulha de tapeçaria
#
#                        8                       9   ... 38 39 40 41 42 43 44  \
# 116                     0                       0  ...  0  0  0  0  0  0  0
# 87                      0                       0  ...  0  0  0  0  0  0  0
# 71                      0                       0  ...  0  0  0  0  0  0  0
# 68       Jogos Americanos     Barbante 4 - Branco  ...  0  0  0  0  0  0  0
# 51                      0                       0  ...  0  0  0  0  0  0  0
# 80   Capas para Almofadas  Lã algodão 4 - Amarelo  ...  0  0  0  0  0  0  0
# 70                      0                       0  ...  0  0  0  0  0  0  0
# 52                      0                       0  ...  0  0  0  0  0  0  0
# 92   Cestas Organizadoras    Lã Amigurumi  - Rosa  ...  0  0  0  0  0  0  0
# 101             Cachecois            Fita métrica  ...  0  0  0  0  0  0  0
#
#     45 46 47
# 116  0  0  0
# 87   0  0  0
# 71   0  0  0
# 68   0  0  0
# 51   0  0  0
# 80   0  0  0
# 70   0  0  0
# 52   0  0  0
# 92   0  0  0
# 101  0  0  0
#
# [10 rows x 48 columns]

# %%
def removeAllZeros(l):
    return list(filter(lambda x: x != 0, l))

# %%
first_list = []
for index, row in df.iterrows():
    listOfMaterial = row.values.tolist()
    listOfMaterial = removeAllZeros(listOfMaterial)

    first_list.append(listOfMaterial)

list_all_material = [[item.split(' -')[0] for item in sublist] for sublist in first_list]

list_all_material[0:10]
# Out:
# [[],
#  ['Meias', 'Lã algodão 2', 'Meias', 'Agulha de Crochê 2,5 mm'],
#  ['Coletes', 'Lã algodão 4', 'Coletes', 'Agulha de Crochê 3,5 mm'],
#  ['Natal',
#   'Barbante 4',
#   'Jogos Americanos',
#   'Barbante 4',
#   'Porta-Copos',
#   'Barbante 4',
#   'Natal',
#   'Barbante 4',
#   'Jogos Americanos',
#   'Barbante 4',
#   'Porta-Copos',
#   'Barbante 4',
#   'Natal',
#   'Agulha de Crochê 4,0 mm',
#   'Jogos Americanos',
#   'Agulha de Crochê 4,0 mm',
#   'Porta-Copos',
#   'Agulha de Crochê 4,0 mm'],
#  ['Bolsas', 'Barbante 4', 'Bolsas', 'Agulha de Crochê Tunisiano 3,5 mm'],
#  ['Capas para Almofadas',
#   'Agulha de Crochê 3,5 mm',
#   'Almofadas',
#   'Agulha de Crochê 3,5 mm',
#   'Capas para Almofadas',
#   'Lã algodão 4',
#   'Almofadas',
#   'Lã algodão 4',
#   'Capas para Almofadas',
#   'Lã algodão 4',
#   'Almofadas',
#   'Lã algodão 4'],
#  ['Babadores',
#   'Barbante 2',
#   'Babadores',
#   'Barbante 2',
#   'Babadores',
#   'Agulha de Crochê 2,0 mm',
#   'Babadores',
#   'Barbante 2'],
#  ['Vestidos', 'Barbante 2', 'Vestidos', 'Agulha de Crochê 3,0 mm'],
#  ['Cestas Organizadoras',
#   'Agulha de Crochê 3,5 mm',
#   'Porta-Lápis',
#   'Agulha de Crochê 3,5 mm',
#   'Cestas Organizadoras',
#   'Lã Amigurumi ',
#   'Porta-Lápis',
#   'Lã Amigurumi ',
#   'Cestas Organizadoras',
#   'Lã Amigurumi ',
#   'Porta-Lápis',
#   'Lã Amigurumi ',
#   'Cestas Organizadoras',
#   'Lã Amigurumi ',
#   'Porta-Lápis',
#   'Lã Amigurumi ',
#   'Cestas Organizadoras',
#   'Lã Amigurumi ',
#   'Porta-Lápis',
#   'Lã Amigurumi '],
#  ['Cachecois',
#   'Lã algodão 4',
#   'Cachecois',
#   'Lã algodão 4',
#   'Cachecois',
#   'Agulha de Crochê 4,0 mm',
#   'Cachecois',
#   'Agulha de tapeçaria',
#   'Cachecois',
#   'Fita métrica']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(list_all_material).transform(list_all_material)
df = pd.DataFrame(te_ary, columns=te.columns_)

df.head(10)
# Out:
#    Agulha de Crochê 2,0 mm  Agulha de Crochê 2,5 mm  Agulha de Crochê 3,0 mm  \
# 0                    False                    False                    False
# 1                    False                     True                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
# 5                    False                    False                    False
# 6                     True                    False                    False
# 7                    False                    False                     True
# 8                    False                    False                    False
# 9                    False                    False                    False
#
#    Agulha de Crochê 3,5 mm  Agulha de Crochê 4,0 mm  Agulha de Crochê 4,5 mm  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                     True                    False                    False
# 3                    False                     True                    False
# 4                    False                    False                    False
# 5                     True                    False                    False
# 6                    False                    False                    False
# 7                    False                    False                    False
# 8                     True                    False                    False
# 9                    False                     True                    False
#
#    Agulha de Crochê 5,0 mm  Agulha de Crochê 5,5 mm  Agulha de Crochê 6,0 mm  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
# 5                    False                    False                    False
# 6                    False                    False                    False
# 7                    False                    False                    False
# 8                    False                    False                    False
# 9                    False                    False                    False
#
#    Agulha de Crochê 7,0 mm  ...  Tapetes  Tapetes de Banheiro  Tesoura  \
# 0                    False  ...    False                False    False
# 1                    False  ...    False                False    False
# 2                    False  ...    False                False    False
# 3                    False  ...    False                False    False
# 4                    False  ...    False                False    False
# 5                    False  ...    False                False    False
# 6                    False  ...    False                False    False
# 7                    False  ...    False                False    False
# 8                    False  ...    False                False    False
# 9                    False  ...    False                False    False
#
#    Toalhas de Mesa  Top Cropped  Toucas e Sapatinhos para Bebe  Vestidos  \
# 0            False        False                          False     False
# 1            False        False                          False     False
# 2            False        False                          False     False
# 3            False        False                          False     False
# 4            False        False                          False     False
# 5            False        False                          False     False
# 6            False        False                          False     False
# 7            False        False                          False      True
# 8            False        False                          False     False
# 9            False        False                          False     False
#
#    Xales  Zíper  Óculos de Segurança
# 0  False  False                False
# 1  False  False                False
# 2  False  False                False
# 3  False  False                False
# 4  False  False                False
# 5  False  False                False
# 6  False  False                False
# 7  False  False                False
# 8  False  False                False
# 9  False  False                False
#
# [10 rows x 98 columns]

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support = 0.06, use_colnames= True)
frequent_itemsets.sort_values(by=['support'], ascending= False)
# Out:
#      support                                           itemsets
# 5   0.341880                              (Agulha de tapeçaria)
# 0   0.196581                          (Agulha de Crochê 2,0 mm)
# 8   0.196581                                       (Barbante 4)
# 19  0.188034                                          (Tesoura)
# 2   0.162393                          (Agulha de Crochê 3,0 mm)
# 3   0.162393                          (Agulha de Crochê 3,5 mm)
# 6   0.162393                                       (Amigurumis)
# 4   0.153846                          (Agulha de Crochê 4,0 mm)
# 30  0.136752                     (Agulha de tapeçaria, Tesoura)
# 15  0.136752                                     (Lã algodão 4)
# 14  0.128205                                     (Lã algodão 2)
# 17  0.128205                                          (Tapetes)
# 11  0.128205                              (Enchimento acrílico)
# 32  0.128205                  (Enchimento acrílico, Amigurumis)
# 13  0.119658                                    (Lã Amigurumi )
# 7   0.119658                                       (Barbante 2)
# 27  0.094017                  (Agulha de tapeçaria, Amigurumis)
# 37  0.094017                     (Tapetes, Tapetes de Banheiro)
# 20  0.094017              (Agulha de Crochê 2,0 mm, Barbante 2)
# 18  0.094017                              (Tapetes de Banheiro)
# 21  0.085470            (Agulha de Crochê 2,0 mm, Lã algodão 2)
# 23  0.085470              (Amigurumis, Agulha de Crochê 3,0 mm)
# 33  0.085470                        (Amigurumis, Lã Amigurumi )
# 28  0.076923         (Agulha de tapeçaria, Enchimento acrílico)
# 38  0.076923  (Agulha de tapeçaria, Enchimento acrílico, Ami...
# 12  0.076923                                     (Fita métrica)
# 25  0.076923              (Agulha de Crochê 3,5 mm, Barbante 4)
# 26  0.068376     (Agulha de tapeçaria, Agulha de Crochê 4,0 mm)
# 16  0.068376                                            (Natal)
# 29  0.068376               (Agulha de tapeçaria, Lã Amigurumi )
# 1   0.068376                          (Agulha de Crochê 2,5 mm)
# 31  0.068376                            (Amigurumis, Bichinhos)
# 10  0.068376                                        (Bichinhos)
# 24  0.068376           (Lã Amigurumi , Agulha de Crochê 3,0 mm)
# 34  0.068376                              (Tapetes, Barbante 4)
# 35  0.068376                   (Enchimento acrílico, Bichinhos)
# 36  0.068376               (Enchimento acrílico, Lã Amigurumi )
# 9   0.068376                                       (Barbante 6)
# 22  0.068376     (Agulha de tapeçaria, Agulha de Crochê 3,0 mm)
# 39  0.068376       (Enchimento acrílico, Amigurumis, Bichinhos)
# 40  0.068376   (Amigurumis, Lã Amigurumi , Enchimento acrílico)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric = 'confidence', min_threshold= 0.5)
sorted_rules = rules.sort_values(by=['confidence'], ascending= False).drop(['antecedent support', 'consequent support', 'leverage', 'conviction', 'support', 'zhangs_metric'], axis=1)
sorted_rules
# Out:
#                                    antecedents  \
# 26            (Enchimento acrílico, Bichinhos)
# 27                     (Amigurumis, Bichinhos)
# 32        (Enchimento acrílico, Lã Amigurumi )
# 21  (Agulha de tapeçaria, Enchimento acrílico)
# 20                       (Tapetes de Banheiro)
# 16                                 (Bichinhos)
# 29                                 (Bichinhos)
# 9                                  (Bichinhos)
# 10                       (Enchimento acrílico)
# 22           (Agulha de tapeçaria, Amigurumis)
# 30                 (Amigurumis, Lã Amigurumi )
# 11                                (Amigurumis)
# 0                                 (Barbante 2)
# 19                                   (Tapetes)
# 8                                    (Tesoura)
# 13                             (Lã Amigurumi )
# 1                               (Lã algodão 2)
# 6                        (Enchimento acrílico)
# 23           (Enchimento acrílico, Amigurumis)
# 24                       (Enchimento acrílico)
# 5                                 (Amigurumis)
# 7                              (Lã Amigurumi )
# 18                             (Lã Amigurumi )
# 4                              (Lã Amigurumi )
# 33                             (Lã Amigurumi )
# 31           (Enchimento acrílico, Amigurumis)
# 28                       (Enchimento acrílico)
# 17                       (Enchimento acrílico)
# 25           (Enchimento acrílico, Amigurumis)
# 15                       (Enchimento acrílico)
# 14                                   (Tapetes)
# 34                       (Enchimento acrílico)
# 12                                (Amigurumis)
# 3                    (Agulha de Crochê 3,0 mm)
# 2                                 (Amigurumis)
#
#                           consequents  confidence      lift
# 26                       (Amigurumis)    1.000000  6.157895
# 27              (Enchimento acrílico)    1.000000  7.800000
# 32                       (Amigurumis)    1.000000  6.157895
# 21                       (Amigurumis)    1.000000  6.157895
# 20                          (Tapetes)    1.000000  7.800000
# 16              (Enchimento acrílico)    1.000000  7.800000
# 29  (Enchimento acrílico, Amigurumis)    1.000000  7.800000
# 9                        (Amigurumis)    1.000000  6.157895
# 10                       (Amigurumis)    1.000000  6.157895
# 22              (Enchimento acrílico)    0.818182  6.381818
# 30              (Enchimento acrílico)    0.800000  6.240000
# 11              (Enchimento acrílico)    0.789474  6.157895
# 0           (Agulha de Crochê 2,0 mm)    0.785714  3.996894
# 19              (Tapetes de Banheiro)    0.733333  7.800000
# 8               (Agulha de tapeçaria)    0.727273  2.127273
# 13                       (Amigurumis)    0.714286  4.398496
# 1           (Agulha de Crochê 2,0 mm)    0.666667  3.391304
# 6               (Agulha de tapeçaria)    0.600000  1.755000
# 23              (Agulha de tapeçaria)    0.600000  1.755000
# 24  (Agulha de tapeçaria, Amigurumis)    0.600000  6.381818
# 5               (Agulha de tapeçaria)    0.578947  1.693421
# 7               (Agulha de tapeçaria)    0.571429  1.671429
# 18              (Enchimento acrílico)    0.571429  4.457143
# 4           (Agulha de Crochê 3,0 mm)    0.571429  3.518797
# 33  (Enchimento acrílico, Amigurumis)    0.571429  4.457143
# 31                    (Lã Amigurumi )    0.533333  4.457143
# 28            (Amigurumis, Bichinhos)    0.533333  7.800000
# 17                    (Lã Amigurumi )    0.533333  4.457143
# 25                        (Bichinhos)    0.533333  7.800000
# 15                        (Bichinhos)    0.533333  7.800000
# 14                       (Barbante 4)    0.533333  2.713043
# 34        (Amigurumis, Lã Amigurumi )    0.533333  6.240000
# 12                    (Lã Amigurumi )    0.526316  4.398496
# 3                        (Amigurumis)    0.526316  3.240997
# 2           (Agulha de Crochê 3,0 mm)    0.526316  3.240997

# %%
sorted_rules['antecedents'] = sorted_rules['antecedents'].apply(lambda x: list(x))
sorted_rules['consequents'] = sorted_rules['consequents'].apply(lambda x: list(x))

sorted_rules.to_csv("regras-material-categoria.csv", index=False)

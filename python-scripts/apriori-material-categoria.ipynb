# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("receitas-ambos.csv", header=None, skiprows=1, names=['materiais_concatenados'])
df['materiais_concatenados'] = df['materiais_concatenados'].str.split(', ')
new_df = pd.DataFrame(df['materiais_concatenados'].to_list())
result_df = pd.concat([df, new_df], axis=1)

result_df.replace(np.nan, 0, inplace=True)
result_df.drop(columns=['materiais_concatenados'], inplace=True)

df = result_df
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Federal\TCC\Lama\Back Lama\python-scripts\apriori-material-categoria.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Federal/TCC/Lama/Back%20Lama/python-scripts/apriori-material-categoria.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("receitas-ambos.csv", header=None, skiprows=1, names=['materiais_concatenados'])
#       <a href='vscode-notebook-cell:/d%3A/Federal/TCC/Lama/Back%20Lama/python-scripts/apriori-material-categoria.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df['materiais_concatenados'] = df['materiais_concatenados'].str.split(', ')
#       <a href='vscode-notebook-cell:/d%3A/Federal/TCC/Lama/Back%20Lama/python-scripts/apriori-material-categoria.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> new_df = pd.DataFrame(df['materiais_concatenados'].to_list())
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'receitas-ambos.csv'

# %%
def removeAllZeros(l):
    return list(filter(lambda x: x != 0, l))

# %%
first_list = []
for index, row in df.iterrows():
    listOfMaterial = row.values.tolist()
    listOfMaterial = removeAllZeros(listOfMaterial)

    first_list.append(listOfMaterial)

list_all_material = [[item.split(' -')[0] for item in sublist] for sublist in first_list]

list_all_material[0:10]
# Out:
# [['porta-shampoo',
#   'Olhos de Gato de Plástico 6mm',
#   'porta-shampoo',
#   'Óculos de Mergulho',
#   'porta-shampoo',
#   'Lã Amigurumi Soft',
#   'porta-shampoo',
#   'Lã Amigurumi Soft'],
#  ['mochilas', 'Boca de Cachorro 12mm', 'mochilas', 'Lã Amigurumi  Pelúcia'],
#  ['cachecois', 'Lã Amigurumi  Pelúcia', 'golas', 'Lã Amigurumi  Pelúcia'],
#  ['capas para garrafas de agua quente',
#   'Óculos de Sol',
#   'capas para garrafas de agua quente',
#   'Lã Amigurumi  Pelúcia',
#   'porta-toalhas',
#   'Óculos de Sol',
#   'porta-toalhas',
#   'Lã Amigurumi  Pelúcia'],
#  ['bichinhos', 'Barbante 8', 'bichinhos', 'Barbante 4'],
#  ['blusas',
#   'Chapéu de Sol',
#   'blusas',
#   'Focinho de Porco 20mm',
#   'blusas',
#   'Lã Amigurumi Soft',
#   'blusas',
#   'Lã Amigurumi  Pelúcia',
#   'capas para livros',
#   'Chapéu de Sol',
#   'capas para livros',
#   'Focinho de Porco 20mm',
#   'capas para livros',
#   'Lã Amigurumi Soft',
#   'capas para livros',
#   'Lã Amigurumi  Pelúcia'],
#  ['saidas de praia',
#   'Agulha de Crochê 4,0 mm',
#   'saidas de praia',
#   'Lã algodão 4',
#   'saidas de praia',
#   'Lã algodão 4'],
#  ['chapeus',
#   'Mini Gorros de Papai Noel',
#   'chapeus',
#   'Bolinhas decorativas',
#   'xales',
#   'Mini Gorros de Papai Noel',
#   'xales',
#   'Bolinhas decorativas'],
#  ['toalhas de mesa',
#   'Lã Amigurumi Soft',
#   'toalhas de mesa',
#   'Lã Amigurumi Soft',
#   'babadores',
#   'Lã Amigurumi Soft',
#   'babadores',
#   'Lã Amigurumi Soft'],
#  ['porta-talheres',
#   'Agulha de Crochê 4,0 mm',
#   'porta-talheres',
#   'Lã algodão 4']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(list_all_material).transform(list_all_material)
df = pd.DataFrame(te_ary, columns=te.columns_)

df.head(10)
# Out:
#    Agulha de Crochê 10,0 mm  Agulha de Crochê 2,5 mm  Agulha de Crochê 3,5 mm  \
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# 5                     False                    False                    False
# 6                     False                    False                    False
# 7                     False                    False                    False
# 8                     False                    False                    False
# 9                     False                    False                    False
#
#    Agulha de Crochê 4,0 mm  Agulha de Crochê 4,5 mm  Agulha de Crochê 5,5 mm  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
# 5                    False                    False                    False
# 6                     True                    False                    False
# 7                    False                    False                    False
# 8                    False                    False                    False
# 9                     True                    False                    False
#
#    Agulha de Crochê 8,0 mm  Agulha de Crochê 9,0 mm  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
# 5                    False                    False
# 6                    False                    False
# 7                    False                    False
# 8                    False                    False
# 9                    False                    False
#
#    Agulha de Crochê Tunisiano 10,0 mm  Agulha de Crochê Tunisiano 2,0 mm  ...  \
# 0                               False                              False  ...
# 1                               False                              False  ...
# 2                               False                              False  ...
# 3                               False                              False  ...
# 4                               False                              False  ...
# 5                               False                              False  ...
# 6                               False                              False  ...
# 7                               False                              False  ...
# 8                               False                              False  ...
# 9                               False                              False  ...
#
#    top cropped  toucas e sapatinhos para bebe  vestidos  xales  \
# 0        False                          False     False  False
# 1        False                          False     False  False
# 2        False                          False     False  False
# 3        False                          False     False  False
# 4        False                          False     False  False
# 5        False                          False     False  False
# 6        False                          False     False  False
# 7        False                          False     False   True
# 8        False                          False     False  False
# 9        False                          False     False  False
#
#    Óculos de Esportes  Óculos de Leitura  Óculos de Mergulho  \
# 0               False              False                True
# 1               False              False               False
# 2               False              False               False
# 3               False              False               False
# 4               False              False               False
# 5               False              False               False
# 6               False              False               False
# 7               False              False               False
# 8               False              False               False
# 9               False              False               False
#
#    Óculos de Natação  Óculos de Segurança  Óculos de Sol
# 0              False                False          False
# 1              False                False          False
# 2              False                False          False
# 3              False                False           True
# 4              False                False          False
# 5              False                False          False
# 6              False                False          False
# 7              False                False          False
# 8              False                False          False
# 9              False                False          False
#
# [10 rows x 146 columns]

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support = 0.01, use_colnames= True)
frequent_itemsets.sort_values(by=['support'], ascending= False)
# Out:
#       support                                           itemsets
# 0    0.265734                          (Agulha de Crochê 4,0 mm)
# 33   0.248751                            (Lã Amigurumi  Pelúcia)
# 34   0.244755                                (Lã Amigurumi Soft)
# 38   0.150849                                     (Lã algodão 8)
# 36   0.125874                                     (Lã algodão 4)
# ..        ...                                                ...
# 139  0.010989                 (almofadas, Lã Amigurumi  Pelúcia)
# 149  0.010989        (Óculos de Mergulho, Lã Amigurumi  Pelúcia)
# 154  0.010989  (enfeites para carrinho de bebe, Lã Amigurumi ...
# 112  0.010989   (conjuntos de lingerie, Agulha de Crochê 4,0 mm)
# 156  0.010989                   (porta-copos, Lã Amigurumi Soft)
#
# [173 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric = 'confidence', min_threshold= 0.5)
sorted_rules = rules.sort_values(by=['confidence'], ascending= False).drop(['antecedent support', 'consequent support', 'leverage', 'conviction', 'support', 'zhangs_metric'], axis=1)
sorted_rules
# Out:
#                             antecedents                consequents  \
# 38      (Lã Amigurumi  Pelúcia, outros)                 (diversos)
# 37    (diversos, Lã Amigurumi  Pelúcia)                   (outros)
# 34           (Lã algodão 4, Barbante 8)  (Agulha de Crochê 4,0 mm)
# 32                             (outros)                 (diversos)
# 31                           (diversos)                   (outros)
# 33           (Barbante 4, Lã algodão 8)  (Agulha de Crochê 4,0 mm)
# 35           (Barbante 8, Lã algodão 8)  (Agulha de Crochê 4,0 mm)
# 36         (Lã algodão 4, Lã algodão 8)  (Agulha de Crochê 4,0 mm)
# 3                        (Lã algodão 8)  (Agulha de Crochê 4,0 mm)
# 1                          (Barbante 8)  (Agulha de Crochê 4,0 mm)
# 21  (Olhos de Cachorro de Pelúcia 12mm)    (Lã Amigurumi  Pelúcia)
# 16              (Focinho de Porco 18mm)        (Lã Amigurumi Soft)
# 0                          (Barbante 4)  (Agulha de Crochê 4,0 mm)
# 2                        (Lã algodão 4)  (Agulha de Crochê 4,0 mm)
# 6                (Boca de Sorriso 15mm)        (Lã Amigurumi Soft)
# 15               (Focinho de Gato 10mm)    (Lã Amigurumi  Pelúcia)
# 12                      (Chapéu de Sol)        (Lã Amigurumi Soft)
# 4                 (Boca de Boneca 12mm)        (Lã Amigurumi Soft)
# 13           (Focinho de Cachorro 12mm)    (Lã Amigurumi  Pelúcia)
# 14           (Focinho de Cachorro 12mm)        (Lã Amigurumi Soft)
# 17              (Focinho de Porco 20mm)    (Lã Amigurumi  Pelúcia)
# 30                  (Óculos de Natação)        (Lã Amigurumi Soft)
# 26     (Olhos de Cachorro de Botão 8mm)        (Lã Amigurumi Soft)
# 20     (Olhos de Cachorro de Botão 8mm)    (Lã Amigurumi  Pelúcia)
# 25     (Olhos de Cachorro de Botão 6mm)        (Lã Amigurumi Soft)
# 19     (Olhos de Cachorro de Botão 6mm)    (Lã Amigurumi  Pelúcia)
# 5               (Boca de Cachorro 12mm)        (Lã Amigurumi Soft)
# 10                    (Chapéu de Palha)    (Lã Amigurumi  Pelúcia)
# 7                (Boca de Sorriso 20mm)    (Lã Amigurumi  Pelúcia)
# 11                    (Chapéu de Palha)        (Lã Amigurumi Soft)
# 22      (Olhos de Gato de Plástico 6mm)    (Lã Amigurumi  Pelúcia)
# 28                 (Óculos de Esportes)        (Lã Amigurumi Soft)
# 29                 (Óculos de Mergulho)        (Lã Amigurumi Soft)
# 18              (Focinho de Porco 20mm)        (Lã Amigurumi Soft)
# 23                 (Óculos de Esportes)    (Lã Amigurumi  Pelúcia)
# 24                 (Óculos de Mergulho)    (Lã Amigurumi  Pelúcia)
# 9                   (Chapéu de Inverno)        (Lã Amigurumi Soft)
# 8                   (Chapéu de Inverno)    (Lã Amigurumi  Pelúcia)
# 27      (Olhos de Gato de Plástico 6mm)        (Lã Amigurumi Soft)
#
#     confidence       lift
# 38    1.000000  30.333333
# 37    1.000000  30.333333
# 34    1.000000   3.763158
# 32    1.000000  30.333333
# 31    1.000000  30.333333
# 33    0.923077   3.473684
# 35    0.913043   3.435927
# 36    0.884615   3.328947
# 3     0.781457   2.940746
# 1     0.777778   2.926901
# 21    0.777778   3.126729
# 16    0.764706   3.124370
# 0     0.750000   2.822368
# 2     0.746032   2.807435
# 6     0.736842   3.010526
# 15    0.722222   2.903391
# 12    0.722222   2.950794
# 4     0.687500   2.808929
# 13    0.684211   2.750581
# 14    0.684211   2.795489
# 17    0.650000   2.613052
# 30    0.647059   2.643697
# 26    0.636364   2.600000
# 20    0.636364   2.558233
# 25    0.631579   2.580451
# 19    0.631579   2.538998
# 5     0.615385   2.514286
# 10    0.611111   2.456716
# 7     0.611111   2.456716
# 11    0.611111   2.496825
# 22    0.608696   2.447005
# 28    0.600000   2.451429
# 29    0.600000   2.451429
# 18    0.600000   2.451429
# 23    0.560000   2.251245
# 24    0.550000   2.211044
# 9     0.550000   2.247143
# 8     0.550000   2.211044
# 27    0.521739   2.131677

# %%
sorted_rules['antecedents'] = sorted_rules['antecedents'].apply(lambda x: list(x))
sorted_rules['consequents'] = sorted_rules['consequents'].apply(lambda x: list(x))

sorted_rules.to_csv("regras-material-categoria.csv", index=False)

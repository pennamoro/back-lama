# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("receitas-material-categoria.csv", header=None, skiprows=1, names=['materiais_concatenados'])
df['materiais_concatenados'] = df['materiais_concatenados'].str.split(', ')
new_df = pd.DataFrame(df['materiais_concatenados'].to_list())
result_df = pd.concat([df, new_df], axis=1)

result_df.replace(np.nan, 0, inplace=True)
result_df.drop(columns=['materiais_concatenados'], inplace=True)

df = result_df
df.head(10)
# Out:
#                       0                             1                   2   \
# 54                Cintos          Lã algodão 2 - Preto              Cintos
# 29  Capas para Almofadas       Agulha de Crochê 3,5 mm           Almofadas
# 4             Cobertores        Lã Amigurumi  - Marrom          Cobertores
# 34             Almofadas       Agulha de Crochê 2,5 mm           Almofadas
# 51              Vestidos      Barbante 4 - Verde Claro            Vestidos
# 52                 Xales       Agulha de Crochê 3,0 mm               Xales
# 67                     0                             0                   0
# 63           Top Cropped           Lã algodão 4 - Rosa         Top Cropped
# 10    Mobiles para Berco        Lã Amigurumi  - Branco  Mobiles para Berco
# 35                 Luvas  Barbante 4 - Vermelho Escuro               Luvas
#
#                                    3                     4   \
# 54            Agulha de Crochê 2,0 mm                Cintos
# 29            Agulha de Crochê 3,5 mm  Capas para Almofadas
# 4             Lã Amigurumi  - Laranja            Cobertores
# 34                Barbante 2 - Branco             Almofadas
# 51  Agulha de Crochê Tunisiano 3,0 mm              Vestidos
# 52                Lã algodão 4 - Azul                     0
# 67                                  0                     0
# 63            Agulha de Crochê 2,0 mm                     0
# 10            Agulha de Crochê 2,5 mm    Mobiles para Berco
# 35            Agulha de Crochê 4,5 mm                 Luvas
#
#                                 5           6                           7   \
# 54             Fivelas para cintos           0                           0
# 29          Lã algodão 4 - Laranja   Almofadas      Lã algodão 4 - Laranja
# 4          Agulha de Crochê 3,5 mm  Cobertores      Lã Amigurumi  - Branco
# 34  Lã Amigurumi Soft - Azul Claro   Almofadas  Lã Amigurumi Soft - Branco
# 51         Agulha de Crochê 3,0 mm           0                           0
# 52                               0           0                           0
# 67                               0           0                           0
# 63                               0           0                           0
# 10             Agulha de tapeçaria           0                           0
# 35             Agulha de tapeçaria       Luvas                   Alfinetes
#
#                       8                                9   ... 14 15 16 17 18  \
# 54                     0                                0  ...  0  0  0  0  0
# 29  Capas para Almofadas           Lã algodão 4 - Amarelo  ...  0  0  0  0  0
# 4                      0                                0  ...  0  0  0  0  0
# 34             Almofadas  Lã Amigurumi Soft - Verde Claro  ...  0  0  0  0  0
# 51                     0                                0  ...  0  0  0  0  0
# 52                     0                                0  ...  0  0  0  0  0
# 67                     0                                0  ...  0  0  0  0  0
# 63                     0                                0  ...  0  0  0  0  0
# 10                     0                                0  ...  0  0  0  0  0
# 35                 Luvas               Marcador de pontos  ...  0  0  0  0  0
#
#    19 20 21 22 23
# 54  0  0  0  0  0
# 29  0  0  0  0  0
# 4   0  0  0  0  0
# 34  0  0  0  0  0
# 51  0  0  0  0  0
# 52  0  0  0  0  0
# 67  0  0  0  0  0
# 63  0  0  0  0  0
# 10  0  0  0  0  0
# 35  0  0  0  0  0
#
# [10 rows x 24 columns]

# %%
def removeAllZeros(l):
    return list(filter(lambda x: x != 0, l))

# %%
first_list = []
for index, row in df.iterrows():
    listOfMaterial = row.values.tolist()
    listOfMaterial = removeAllZeros(listOfMaterial)

    first_list.append(listOfMaterial)

list_all_material = [[item.split(' -')[0] for item in sublist] for sublist in first_list]

list_all_material[0:10]
# Out:
# [['Cintos',
#   'Lã algodão 2',
#   'Cintos',
#   'Agulha de Crochê 2,0 mm',
#   'Cintos',
#   'Fivelas para cintos'],
#  ['Capas para Almofadas',
#   'Agulha de Crochê 3,5 mm',
#   'Almofadas',
#   'Agulha de Crochê 3,5 mm',
#   'Capas para Almofadas',
#   'Lã algodão 4',
#   'Almofadas',
#   'Lã algodão 4',
#   'Capas para Almofadas',
#   'Lã algodão 4',
#   'Almofadas',
#   'Lã algodão 4'],
#  ['Cobertores',
#   'Lã Amigurumi ',
#   'Cobertores',
#   'Lã Amigurumi ',
#   'Cobertores',
#   'Agulha de Crochê 3,5 mm',
#   'Cobertores',
#   'Lã Amigurumi '],
#  ['Almofadas',
#   'Agulha de Crochê 2,5 mm',
#   'Almofadas',
#   'Barbante 2',
#   'Almofadas',
#   'Lã Amigurumi Soft',
#   'Almofadas',
#   'Lã Amigurumi Soft',
#   'Almofadas',
#   'Lã Amigurumi Soft',
#   'Almofadas',
#   'Óculos de Segurança',
#   'Almofadas',
#   'Agulha de Crochê 2,5 mm'],
#  ['Vestidos',
#   'Barbante 4',
#   'Vestidos',
#   'Agulha de Crochê Tunisiano 3,0 mm',
#   'Vestidos',
#   'Agulha de Crochê 3,0 mm'],
#  ['Xales', 'Agulha de Crochê 3,0 mm', 'Xales', 'Lã algodão 4'],
#  [],
#  ['Top Cropped', 'Lã algodão 4', 'Top Cropped', 'Agulha de Crochê 2,0 mm'],
#  ['Mobiles para Berco',
#   'Lã Amigurumi ',
#   'Mobiles para Berco',
#   'Agulha de Crochê 2,5 mm',
#   'Mobiles para Berco',
#   'Agulha de tapeçaria'],
#  ['Luvas',
#   'Barbante 4',
#   'Luvas',
#   'Agulha de Crochê 4,5 mm',
#   'Luvas',
#   'Agulha de tapeçaria',
#   'Luvas',
#   'Alfinetes',
#   'Luvas',
#   'Marcador de pontos']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(list_all_material).transform(list_all_material)
df = pd.DataFrame(te_ary, columns=te.columns_)

df.head(10)
# Out:
#    Agulha de Crochê 2,0 mm  Agulha de Crochê 2,5 mm  Agulha de Crochê 3,0 mm  \
# 0                     True                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                     True                    False
# 4                    False                    False                     True
# 5                    False                    False                     True
# 6                    False                    False                    False
# 7                     True                    False                    False
# 8                    False                     True                    False
# 9                    False                    False                    False
#
#    Agulha de Crochê 3,5 mm  Agulha de Crochê 4,0 mm  Agulha de Crochê 4,5 mm  \
# 0                    False                    False                    False
# 1                     True                    False                    False
# 2                     True                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
# 5                    False                    False                    False
# 6                    False                    False                    False
# 7                    False                    False                    False
# 8                    False                    False                    False
# 9                    False                    False                     True
#
#    Agulha de Crochê 5,0 mm  Agulha de Crochê 6,0 mm  Agulha de Crochê 7,0 mm  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
# 5                    False                    False                    False
# 6                    False                    False                    False
# 7                    False                    False                    False
# 8                    False                    False                    False
# 9                    False                    False                    False
#
#    Agulha de Crochê Tunisiano 2,0 mm  ...  Tapetes  Tapetes de Banheiro  \
# 0                              False  ...    False                False
# 1                              False  ...    False                False
# 2                              False  ...    False                False
# 3                              False  ...    False                False
# 4                              False  ...    False                False
# 5                              False  ...    False                False
# 6                              False  ...    False                False
# 7                              False  ...    False                False
# 8                              False  ...    False                False
# 9                              False  ...    False                False
#
#    Tesoura  Toalhas de Mesa  Top Cropped  Toucas e Sapatinhos para Bebe  \
# 0    False            False        False                          False
# 1    False            False        False                          False
# 2    False            False        False                          False
# 3    False            False        False                          False
# 4    False            False        False                          False
# 5    False            False        False                          False
# 6    False            False        False                          False
# 7    False            False         True                          False
# 8    False            False        False                          False
# 9    False            False        False                          False
#
#    Vestidos  Xales  Zíper  Óculos de Segurança
# 0     False  False  False                False
# 1     False  False  False                False
# 2     False  False  False                False
# 3     False  False  False                 True
# 4      True  False  False                False
# 5     False   True  False                False
# 6     False  False  False                False
# 7     False  False  False                False
# 8     False  False  False                False
# 9     False  False  False                False
#
# [10 rows x 87 columns]

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support = 0.05, use_colnames= True)
frequent_itemsets.sort_values(by=['support'], ascending= False)
# Out:
#      support                                        itemsets
# 6   0.294118                           (Agulha de tapeçaria)
# 9   0.220588                                    (Barbante 4)
# 0   0.205882                       (Agulha de Crochê 2,0 mm)
# 3   0.205882                       (Agulha de Crochê 3,5 mm)
# 23  0.205882                                       (Tesoura)
# 18  0.176471                                  (Lã algodão 2)
# 19  0.176471                                  (Lã algodão 4)
# 2   0.161765                       (Agulha de Crochê 3,0 mm)
# 36  0.132353                  (Agulha de tapeçaria, Tesoura)
# 16  0.132353                                 (Lã Amigurumi )
# 1   0.117647                       (Agulha de Crochê 2,5 mm)
# 8   0.117647                                    (Barbante 2)
# 7   0.102941                                    (Amigurumis)
# 21  0.102941                            (Marcador de pontos)
# 26  0.102941         (Lã algodão 2, Agulha de Crochê 2,0 mm)
# 4   0.088235                       (Agulha de Crochê 4,0 mm)
# 25  0.073529           (Barbante 2, Agulha de Crochê 2,0 mm)
# 35  0.073529       (Marcador de pontos, Agulha de tapeçaria)
# 27  0.073529  (Agulha de Crochê 2,5 mm, Agulha de tapeçaria)
# 30  0.073529         (Lã algodão 4, Agulha de Crochê 3,5 mm)
# 32  0.073529               (Agulha de tapeçaria, Barbante 4)
# 37  0.073529                     (Lã Amigurumi , Amigurumis)
# 24  0.073529                                   (Top Cropped)
# 20  0.073529                                  (Lã algodão 6)
# 5   0.073529                       (Agulha de Crochê 5,0 mm)
# 22  0.058824                                         (Natal)
# 33  0.058824            (Lã Amigurumi , Agulha de tapeçaria)
# 39  0.058824                         (Tesoura, Fita métrica)
# 38  0.058824                           (Tesoura, Barbante 4)
# 10  0.058824                                    (Barbante 6)
# 11  0.058824                            (Barbante Natural 4)
# 34  0.058824             (Lã algodão 4, Agulha de tapeçaria)
# 12  0.058824                            (Barbante Natural 6)
# 17  0.058824                             (Lã Amigurumi Soft)
# 31  0.058824  (Agulha de tapeçaria, Agulha de Crochê 5,0 mm)
# 13  0.058824                                        (Bolsas)
# 29  0.058824           (Agulha de Crochê 3,5 mm, Barbante 4)
# 28  0.058824         (Lã algodão 4, Agulha de Crochê 3,0 mm)
# 14  0.058824                                  (Fita métrica)
# 15  0.058824                                         (Fitas)
# 40  0.058824                          (Top Cropped, Tesoura)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric = 'confidence', min_threshold= 0.5)
sorted_rules = rules.sort_values(by=['confidence'], ascending= False).drop(['antecedent support', 'consequent support', 'leverage', 'conviction', 'support', 'zhangs_metric'], axis=1)
sorted_rules
# Out:
#                   antecedents                consequents  confidence      lift
# 9              (Fita métrica)                  (Tesoura)    1.000000  4.857143
# 4   (Agulha de Crochê 5,0 mm)      (Agulha de tapeçaria)    0.800000  2.720000
# 10              (Top Cropped)                  (Tesoura)    0.800000  3.885714
# 5        (Marcador de pontos)      (Agulha de tapeçaria)    0.714286  2.428571
# 8                (Amigurumis)            (Lã Amigurumi )    0.714286  5.396825
# 6                   (Tesoura)      (Agulha de tapeçaria)    0.642857  2.185714
# 0                (Barbante 2)  (Agulha de Crochê 2,0 mm)    0.625000  3.035714
# 3   (Agulha de Crochê 2,5 mm)      (Agulha de tapeçaria)    0.625000  2.125000
# 1              (Lã algodão 2)  (Agulha de Crochê 2,0 mm)    0.583333  2.833333
# 7             (Lã Amigurumi )               (Amigurumis)    0.555556  5.396825
# 2   (Agulha de Crochê 2,0 mm)             (Lã algodão 2)    0.500000  2.833333

# %%
sorted_rules['antecedents'] = sorted_rules['antecedents'].apply(lambda x: list(x))
sorted_rules['consequents'] = sorted_rules['consequents'].apply(lambda x: list(x))

sorted_rules.to_csv("regras-material-categoria.csv", index=False)

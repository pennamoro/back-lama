# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("receitas-categorias.csv", header=None, skiprows=1, names=['materiais_concatenados'])
df['materiais_concatenados'] = df['materiais_concatenados'].str.split(', ')
new_df = pd.DataFrame(df['materiais_concatenados'].to_list())
result_df = pd.concat([df, new_df], axis=1)

result_df.replace(np.nan, 0, inplace=True)
result_df.drop(columns=['materiais_concatenados'], inplace=True)

df = result_df
df.head(10)
# Out:
#                                     0                  1  2  3
# 0                             colares                  0  0  0
# 1                cestas organizadoras                  0  0  0
# 2                       porta-shampoo                  0  0  0
# 3                            mochilas                  0  0  0
# 4                           cachecois              golas  0  0
# 5  capas para garrafas de agua quente      porta-toalhas  0  0
# 6                           bichinhos                  0  0  0
# 7                              blusas  capas para livros  0  0
# 8                     saidas de praia                  0  0  0
# 9                             chapeus              xales  0  0

# %%
def removeAllZeros(l):
    return list(filter(lambda x: x != 0, l))

# %%
first_list = []
for index, row in df.iterrows():
    listOfMaterial = row.values.tolist()
    listOfMaterial = removeAllZeros(listOfMaterial)

    first_list.append(listOfMaterial)

list_all_material = first_list

list_all_material[0:10]
# Out:
# [['colares'],
#  ['cestas organizadoras'],
#  ['porta-shampoo'],
#  ['mochilas'],
#  ['cachecois', 'golas'],
#  ['capas para garrafas de agua quente', 'porta-toalhas'],
#  ['bichinhos'],
#  ['blusas', 'capas para livros'],
#  ['saidas de praia'],
#  ['chapeus', 'xales']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(list_all_material).transform(list_all_material)
df = pd.DataFrame(te_ary, columns=te.columns_)

df.head(10)
# Out:
#    almofadas  amigurumis  animais de pelucia  babadores  bichinhos  biquinis  \
# 0      False       False               False      False      False     False
# 1      False       False               False      False      False     False
# 2      False       False               False      False      False     False
# 3      False       False               False      False      False     False
# 4      False       False               False      False      False     False
# 5      False       False               False      False      False     False
# 6      False       False               False      False       True     False
# 7      False       False               False      False      False     False
# 8      False       False               False      False      False     False
# 9      False       False               False      False      False     False
#
#    blusas  bolsas  bolsas de tablet/laptop  bonecos  ...  porta-talheres  \
# 0   False   False                    False    False  ...           False
# 1   False   False                    False    False  ...           False
# 2   False   False                    False    False  ...           False
# 3   False   False                    False    False  ...           False
# 4   False   False                    False    False  ...           False
# 5   False   False                    False    False  ...           False
# 6   False   False                    False    False  ...           False
# 7    True   False                    False    False  ...           False
# 8   False   False                    False    False  ...           False
# 9   False   False                    False    False  ...           False
#
#    porta-toalhas  saidas de praia  tapetes  tapetes de banheiro  \
# 0          False            False    False                False
# 1          False            False    False                False
# 2          False            False    False                False
# 3          False            False    False                False
# 4          False            False    False                False
# 5           True            False    False                False
# 6          False            False    False                False
# 7          False            False    False                False
# 8          False             True    False                False
# 9          False            False    False                False
#
#    toalhas de mesa  top cropped  toucas e sapatinhos para bebe  vestidos  \
# 0            False        False                          False     False
# 1            False        False                          False     False
# 2            False        False                          False     False
# 3            False        False                          False     False
# 4            False        False                          False     False
# 5            False        False                          False     False
# 6            False        False                          False     False
# 7            False        False                          False     False
# 8            False        False                          False     False
# 9            False        False                          False     False
#
#    xales
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
# 5  False
# 6  False
# 7  False
# 8  False
# 9   True
#
# [10 rows x 50 columns]

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support = 0.01, use_colnames= True)
frequent_itemsets.sort_values(by=['support'], ascending= False)
# Out:
#      support                                    itemsets
# 24  0.061061                                  (cortinas)
# 49  0.043043                                     (xales)
# 3   0.041041                                 (babadores)
# 2   0.040040                        (animais de pelucia)
# 42  0.040040                           (saidas de praia)
# 27  0.040040                                     (golas)
# 22  0.037037                                   (coletes)
# 14  0.036036                         (capas para livros)
# 17  0.035035                                   (chapeus)
# 13  0.035035        (capas para garrafas de agua quente)
# 8   0.035035                   (bolsas de tablet/laptop)
# 10  0.035035                                 (cachecois)
# 23  0.033033                     (conjuntos de lingerie)
# 25  0.033033                                  (diversos)
# 28  0.033033                                    (gorros)
# 35  0.033033                                    (outros)
# 37  0.033033                               (porta-copos)
# 34  0.033033                                  (mochilas)
# 50  0.033033                          (diversos, outros)
# 15  0.033033                  (capas para tampa de vaso)
# 38  0.032032                           (porta-sabonetes)
# 9   0.032032                                   (bonecos)
# 43  0.032032                                   (tapetes)
# 29  0.031031                          (jogos americanos)
# 41  0.030030                             (porta-toalhas)
# 21  0.030030                                   (colares)
# 40  0.030030                            (porta-talheres)
# 16  0.029029                      (cestas organizadoras)
# 47  0.029029             (toucas e sapatinhos para bebe)
# 39  0.029029                             (porta-shampoo)
# 45  0.029029                           (toalhas de mesa)
# 4   0.028028                                 (bichinhos)
# 26  0.028028            (enfeites para carrinho de bebe)
# 11  0.028028                      (capas para almofadas)
# 20  0.028028                                (cobertores)
# 6   0.028028                                    (blusas)
# 46  0.027027                               (top cropped)
# 18  0.027027                                 (chaveiros)
# 7   0.027027                                    (bolsas)
# 19  0.026026                                    (cintos)
# 36  0.026026                            (panos de prato)
# 1   0.026026                                (amigurumis)
# 33  0.025025                        (mobiles para berco)
# 0   0.025025                                 (almofadas)
# 5   0.023023                                  (biquinis)
# 44  0.023023                       (tapetes de banheiro)
# 32  0.022022                                     (meias)
# 48  0.022022                                  (vestidos)
# 31  0.019019                          (mantas para bebe)
# 12  0.019019  (capas para almofadas de agulhas de trico)
# 30  0.018018                                     (luvas)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric = 'confidence', min_threshold= 0.5)
sorted_rules = rules.sort_values(by=['confidence'], ascending= False).drop(['antecedent support', 'consequent support', 'leverage', 'conviction', 'support', 'zhangs_metric'], axis=1)
sorted_rules
# Out:
#   antecedents consequents  confidence       lift
# 0  (diversos)    (outros)         1.0  30.272727
# 1    (outros)  (diversos)         1.0  30.272727

# %%
sorted_rules['antecedents'] = sorted_rules['antecedents'].apply(lambda x: list(x))
sorted_rules['consequents'] = sorted_rules['consequents'].apply(lambda x: list(x))

sorted_rules.to_csv("regras-categoria.csv", index=False)
